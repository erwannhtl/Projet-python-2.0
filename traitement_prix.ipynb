# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

html_content = """
  <div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="0"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-traditionnel-old-nick-3012991302039"
  title="Rhum blanc traditionnel OLD NICK"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/d00b59774d4b3a41be251e4924e2d229/p_200x200/03012991302039-h1n1-s27.jpg"        loading="lazy"
    alt="Rhum blanc traditionnel OLD NICK"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3012991302039"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            9,95
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        30% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-traditionnel-old-nick-3012991302039"
  title="Rhum blanc traditionnel OLD NICK"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc traditionnel OLD NICK
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      14.21 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="1"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-charrette-3377450000018"
  title="Rhum blanc CHARRETTE"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/f1e9bd84ad083c118df3d80a7dd3f57a/p_200x200/03377450000018-a1n1-s01.jpg"        loading="lazy"
    alt="Rhum blanc CHARRETTE"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3377450000018"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,69
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 2€ de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-charrette-3377450000018"
  title="Rhum blanc CHARRETTE"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc CHARRETTE
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  100cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      15.69 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="2"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrange-banane-flambee-isautier-3283770211174"
  title="Rhum arrangé banane flambée ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/e56c08d067de355797531d8a61ad8102/p_200x200/03283770211174-a1r1-s01.jpg"        loading="lazy"
    alt="Rhum arrangé banane flambée ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211174"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrange-banane-flambee-isautier-3283770211174"
  title="Rhum arrangé banane flambée ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrangé banane flambée ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="3"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrange-de-noel-isautier-3283770211297"
  title="Rhum arrangé de Noël ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/e4f5111a8a283911a11e4147011d1b94/p_200x200/03283770211297-a1n0-s01.jpg"        loading="lazy"
    alt="Rhum arrangé de Noël ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211297"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrange-de-noel-isautier-3283770211297"
  title="Rhum arrangé de Noël ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrangé de Noël ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="4"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-black-spiced-the-kraken-0811538013062"
  title="Rhum Black Spiced THE KRAKEN"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/589f67c65133353a9fb6fee9fcb17e46/p_200x200/00811538013062-c1n1-s11.jpg"        loading="lazy"
    alt="Rhum Black Spiced THE KRAKEN"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="0811538013062"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            27,49
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 4€ de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-black-spiced-the-kraken-0811538013062"
  title="Rhum Black Spiced THE KRAKEN"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum Black Spiced THE KRAKEN
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      39.27 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="5"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrange-coco-banane-isautier-3283770211549"
  title="Rhum arrangé coco banane ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/8e0761c354f03a7cbc969540a36775e9/p_200x200/03283770211549-a1n1-s01.jpg"        loading="lazy"
    alt="Rhum arrangé coco banane ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211549"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,34
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrange-coco-banane-isautier-3283770211549"
  title="Rhum arrangé coco banane ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrangé coco banane ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      30.68 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="6"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrange-letchi-passion-isautier-3283770211419"
  title="Rhum arrangé letchi passion ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/72402522eebb3a299f9dc8c9fd0aa752/p_200x200/03283770211419-a1n1-s01.jpg"        loading="lazy"
    alt="Rhum arrangé letchi passion ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211419"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrange-letchi-passion-isautier-3283770211419"
  title="Rhum arrangé letchi passion ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrangé letchi passion ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="7"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-agricole-dillon-3012993070776"
  title="Rhum  blanc agricole DILLON"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/ac31b406f9c739a495307caea21a55bd/p_200x200/03012993070776-c1n1-s29.jpg"        loading="lazy"
    alt="Rhum  blanc agricole DILLON"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3012993070776"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            13,55
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        30% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-agricole-dillon-3012993070776"
  title="Rhum  blanc agricole DILLON"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum  blanc agricole DILLON
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      19.36 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="8"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrange-saveur-mandarine-sauvage-isautier-3283770211730"
  title="Rhum arrangé saveur mandarine sauvage ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/a22f95f2c70b3b4db2138f2ebf3654d8/p_200x200/03283770211730-c1n1-s01.jpg"        loading="lazy"
    alt="Rhum arrangé saveur mandarine sauvage ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211730"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrange-saveur-mandarine-sauvage-isautier-3283770211730"
  title="Rhum arrangé saveur mandarine sauvage ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrangé saveur mandarine sauvage ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="9"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-traditionnel-isautier-3283770111115"
  title="Rhum blanc traditionnel ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/54b373be02dc36b989d0c61b4be21752/p_200x200/03283770111115-a1n1-s04.jpg"        loading="lazy"
    alt="Rhum blanc traditionnel ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770111115"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,99
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        15% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-traditionnel-isautier-3283770111115"
  title="Rhum blanc traditionnel ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc traditionnel ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  1L
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      15.99 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="10"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-traditionnel-isautier-3283770111146"
  title="Rhum blanc traditionnel  ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/507fa755e4dd33c2b07a651dcac3089f/p_200x200/03283770111146-a1n1-s06.jpg"        loading="lazy"
    alt="Rhum blanc traditionnel  ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770111146"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            13,45
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        15% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-traditionnel-isautier-3283770111146"
  title="Rhum blanc traditionnel  ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc traditionnel  ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  1L
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      13.45 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="11"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-tres-vieux-agricole-dillon-3012997716304"
  title="Rhum très vieux agricole DILLON"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/5f64034a1ba2308e92095edd9da50c6d/p_200x200/03012997716304-c1n1-s08.jpg"        loading="lazy"
    alt="Rhum très vieux agricole DILLON"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3012997716304"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            21,89
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        30% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-tres-vieux-agricole-dillon-3012997716304"
  title="Rhum très vieux agricole DILLON"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum très vieux agricole DILLON
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      31.27 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="12"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrang-epice-ananas-victoria-isautier-3283770211402"
  title="Rhum arrang&#039;epice ananas victoria ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/532a69d942533fbdb5aae27a38919e24/p_200x200/03283770211402-c1n1-s02.jpg"        loading="lazy"
    alt="Rhum arrang&#039;epice ananas victoria ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211402"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrang-epice-ananas-victoria-isautier-3283770211402"
  title="Rhum arrang&#039;epice ananas victoria ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrang&#039;epice ananas victoria ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="13"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-traditionnel-old-nick-3012993028289"
  title="Rhum blanc traditionnel OLD NICK"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/72c34e22eef131f9a6fa6994dcdd0a81/p_200x200/03012993028289-h1n1-s17.jpg"        loading="lazy"
    alt="Rhum blanc traditionnel OLD NICK"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3012993028289"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            16,19
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        Vu en catalogue
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-traditionnel-old-nick-3012993028289"
  title="Rhum blanc traditionnel OLD NICK"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc traditionnel OLD NICK
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  1L
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      16.19 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="14"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/liqueur-a-base-de-rhum-arrange-cafe-vanille-isautier-3283770565246"
  title="Liqueur à base de Rhum arrangé café vanille ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/8fffa66fdf153ffd84f06b85f86220ba/p_200x200/03283770565246-c1n1-s04.jpg"        loading="lazy"
    alt="Liqueur à base de Rhum arrangé café vanille ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770565246"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/liqueur-a-base-de-rhum-arrange-cafe-vanille-isautier-3283770565246"
  title="Liqueur à base de Rhum arrangé café vanille ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Liqueur à base de Rhum arrangé café vanille ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="15"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/liqueur-a-base-de-rhum-arrange-gingembre-citron-isautier-3283770555254"
  title="Liqueur à base de Rhum arrangé gingembre citron ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/d6e959e1962e3c9087b3240cea3de6ba/p_200x200/03283770555254-c1n1-s04.jpg"        loading="lazy"
    alt="Liqueur à base de Rhum arrangé gingembre citron ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770555254"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/liqueur-a-base-de-rhum-arrange-gingembre-citron-isautier-3283770555254"
  title="Liqueur à base de Rhum arrangé gingembre citron ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Liqueur à base de Rhum arrangé gingembre citron ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="16"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-arrangee-caramelisee-isautier-3283770211815"
  title="Rhum arrangée caramélisée ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/23cbe47e42de3f7e97a2b7452eb26cb2/p_200x200/03283770211815-a1n1-s01.jpg"        loading="lazy"
    alt="Rhum arrangée caramélisée ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211815"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            14,53
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-arrangee-caramelisee-isautier-3283770211815"
  title="Rhum arrangée caramélisée ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum arrangée caramélisée ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  50cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      29.06 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="17"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-presidente-marti-3760042529972"
  title="Rhum blanc PRESIDENTE MARTI"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/96cb7c867ba33dac8587836fcab5d802/p_200x200/03760042529972-a1r1-s01.jpg"        loading="lazy"
    alt="Rhum blanc PRESIDENTE MARTI"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3760042529972"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            27,10
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 4€ de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-presidente-marti-3760042529972"
  title="Rhum blanc PRESIDENTE MARTI"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc PRESIDENTE MARTI
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      38.71 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="18"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-roast-coffee-the-kraken-0818844026199"
  title="Rhum Roast Coffee THE KRAKEN"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/0155116242493a448b2322b019e5474d/p_200x200/00818844026199-c1n1-s01.jpg"        loading="lazy"
    alt="Rhum Roast Coffee THE KRAKEN"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="0818844026199"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            27,49
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 4€ de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-roast-coffee-the-kraken-0818844026199"
  title="Rhum Roast Coffee THE KRAKEN"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum Roast Coffee THE KRAKEN
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cl
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      39.27 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                



          
        
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="19"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-boel-guilly-3245395335123"
  title="Rhum blanc BOEL GUILLY"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/d467a464bbab3ba7ae7e5772d1ce2bfb/p_200x200/03245395335123-a1c1-s01.jpg"        loading="lazy"
    alt="Rhum blanc BOEL GUILLY"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3245395335123"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--default product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            8,89
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
              
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-boel-guilly-3245395335123"
  title="Rhum blanc BOEL GUILLY"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc BOEL GUILLY
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      12.70 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="20"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-ambre-des-iles-old-nick-3012993077546"
  title="Rhum ambré des îles OLD NICK"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/452271ad47de3a0fb0f8ed68213a9ba3/p_200x200/03012993077546-h1n1-s13.jpg"        loading="lazy"
    alt="Rhum ambré des îles OLD NICK"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3012993077546"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            11,85
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        30% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-ambre-des-iles-old-nick-3012993077546"
  title="Rhum ambré des îles OLD NICK"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum ambré des îles OLD NICK
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
        
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      16.93 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="21"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-ambree-arrange-banane-flambee-isautier-3283770211167"
  title="Rhum ambrée arrangé banane flambée ISAUTIER"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/c3b6cc7da12237d3a7250e379658509e/p_200x200/03283770211167-c1n1-s02.jpg"        loading="lazy"
    alt="Rhum ambrée arrangé banane flambée ISAUTIER"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3283770211167"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            23,21
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
              <div class="product-price__amount product-price__amount--old">
          <span class="product-price__amount-value">
            0,00
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
      </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        1 acheté = 10% de remise
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-ambree-arrange-banane-flambee-isautier-3283770211167"
  title="Rhum ambrée arrangé banane flambée ISAUTIER"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum ambrée arrangé banane flambée ISAUTIER
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      33.16 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="22"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-spiced-350-edition-limitee-fa-bacardi-3011932034404"
  title="Rhum Spiced 35° Edition Limitée FA BACARDI"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/1bd19744599936dca9e1d71bed928858/p_200x200/03011932034404-c1n1-s01.jpg"        loading="lazy"
    alt="Rhum Spiced 35° Edition Limitée FA BACARDI"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3011932034404"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,20
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        20% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-spiced-350-edition-limitee-fa-bacardi-3011932034404"
  title="Rhum Spiced 35° Edition Limitée FA BACARDI"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum Spiced 35° Edition Limitée FA BACARDI
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cl
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      21.71 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="23"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-carta-blanca-37-50-edition-limitee-bacardi-3011932034336"
  title="Rhum Carta Blanca 37.5° Edition Limitée BACARDI"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/352f3773acd83de2975b5fd36db51b7a/p_200x200/03011932034336-c1n1-s01.jpg"        loading="lazy"
    alt="Rhum Carta Blanca 37.5° Edition Limitée BACARDI"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3011932034336"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,20
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        20% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-carta-blanca-37-50-edition-limitee-bacardi-3011932034336"
  title="Rhum Carta Blanca 37.5° Edition Limitée BACARDI"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum Carta Blanca 37.5° Edition Limitée BACARDI
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cl
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      21.71 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="24"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-carta-oro-37-50-edition-limitee-fa-bacardi-3011932034374"
  title="Rhum Carta Oro 37.5° Edition Limitée FA BACARDI"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/d02d072315ce3aa49ef7637e223fc139/p_200x200/03011932034374-c1n1-s01.jpg"        loading="lazy"
    alt="Rhum Carta Oro 37.5° Edition Limitée FA BACARDI"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3011932034374"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--loyalty product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,20
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description promotion-description--loyalty">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__loyalty">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i55" />
    </svg>
                        <span class="promotion-label-refonte__label">
        20% d&#039;économies
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-carta-oro-37-50-edition-limitee-fa-bacardi-3011932034374"
  title="Rhum Carta Oro 37.5° Edition Limitée FA BACARDI"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum Carta Oro 37.5° Edition Limitée FA BACARDI
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cl
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      21.71 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="25"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-agricole-imperial-saint-james-3255537505079"
  title="Rhum blanc agricole impérial SAINT JAMES"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/06abe4632e603d939777742b56fd7103/p_200x200/03255537505079-h1n1-s21.jpg"        loading="lazy"
    alt="Rhum blanc agricole impérial SAINT JAMES"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3255537505079"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            12,75
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        Vu en catalogue
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-agricole-imperial-saint-james-3255537505079"
  title="Rhum blanc agricole impérial SAINT JAMES"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc agricole impérial SAINT JAMES
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      18.21 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                



          
        
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="26"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-agricole-trois-rivieres-3267130003104"
  title="Rhum blanc agricole TROIS RIVIERES"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/e6d0e242d895302b83a6c6a73f209136/p_200x200/03267130003104-a1n1-s01.jpg"        loading="lazy"
    alt="Rhum blanc agricole TROIS RIVIERES"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3267130003104"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--default product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            21,19
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
              
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-agricole-trois-rivieres-3267130003104"
  title="Rhum blanc agricole TROIS RIVIERES"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc agricole TROIS RIVIERES
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  100cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      21.19 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="27"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-agricole-de-la-guadeloupe-bologne-3305108971007"
  title="Rhum agricole de la Guadeloupe BOLOGNE"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/c795d65c425b3067b185b4d070faf53c/p_200x200/03305108971007-a1c1-s02.jpg"        loading="lazy"
    alt="Rhum agricole de la Guadeloupe BOLOGNE"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3305108971007"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            20,09
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        Vu en catalogue
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-agricole-de-la-guadeloupe-bologne-3305108971007"
  title="Rhum agricole de la Guadeloupe BOLOGNE"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum agricole de la Guadeloupe BOLOGNE
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  1L
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      20.09 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="28"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-blanc-guadeloupe-damoiseau-3290370000015"
  title="Rhum blanc Guadeloupe DAMOISEAU"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/764f8633539839339d07c4a1f955a25e/p_200x200/03290370000015-a1r0-s01.jpg"        loading="lazy"
    alt="Rhum blanc Guadeloupe DAMOISEAU"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3290370000015"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            20,59
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        Vu en catalogue
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-blanc-guadeloupe-damoiseau-3290370000015"
  title="Rhum blanc Guadeloupe DAMOISEAU"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum blanc Guadeloupe DAMOISEAU
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  100cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      20.59 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
          <li class="product-grid-item ">
                                


          
  
          
                          
  
  



<div
  is="ds-product-card-refonte"
  class="ds-product-card-refonte__twigwrap"
  :index="29"
  layout="main-vertical"
  :lazy ="true"
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
  <article class="ds-product-card-refonte main-vertical">
  
  <div class="main-vertical--top">
    <div class="main-vertical--image">
              
<a
  href="/p/rhum-royal-ambre-agricole-saint-james-3255537503075"
  title="Rhum Royal Ambré agricole SAINT JAMES"
  rel=""
  target=""
  class="product-card-image"
>
  <img
      src="/images/loader-dots.svg"        data-src="https://media.carrefour.fr/medias/93d26e2bfd4a3e81832f5c663b6d04bb/p_200x200/03255537503075-h1n1-s14.jpg"        loading="lazy"
    alt="Rhum Royal Ambré agricole SAINT JAMES"
  class="image image--hidden image--lazy product-card-image__image"
/>
</a>
      
      <div class="main-vertical--pastilles">
                                                                                                                                                                                        
                  <div class="main-vertical--badges">
                    
                  

  <ul
    class="product-badges-list"
    is="product-badges-list"
    :flags="[&quot;flag.common.vegetarian&quot;]"
    :modifiers="[]"
  >
                            <li class="product-badges-list__item">
            
<button class="product-badge__link product-badge--flag-common-vegetari" data-flag-id="flag.common.vegetarian">
  <picture class="product-badge__icon">
    <img
      src="/images/badges/flag-common-vegetarian.svg"         alt="Végétarien"
  class="image product-badge__icon__img"
/>
  </picture>
  <span class="product-badge__title">Végétarien</span>
</button>
          </li>
                    </ul>
              
          </div>
                      </div>
              <div class="main-vertical--shopping-list">
          <div
  class="add-to-shoppinglist"
  ean="3255537503075"
  is="add-to-shoppinglist"
></div>

          
        </div>
          </div>
  </div>
  <div class="main-vertical--bottom">
    <div class="main-vertical--bottom__first">
      <div class="main-vertical--price-top">
        
      </div>
      <div class="main-vertical--flex">
        <div class="main-vertical--price">
                      <div class="product-price product-price--size-l product-price--promo product-price--inline-amounts">
  <div class="product-price__amounts">
          <div class="product-price__amount product-price__amount--main">
          <span class="product-price__amount-value">
            15,55
          </span>
        <span class="product-price__amount-currency">€</span>
      </div>
          </div>
</div>
      
          
        </div>
                  
<form
  is="add-to-cart"
  id="data-produit-acheter"
  class="add-to-cart"
  offer-service-id="0261-150-6"
  basket-service-id=""
  :render-context="{&quot;zone&quot;:&quot;search-results&quot;}" >
      

  


<button
    name=""    class="ds-button ds-button--primary ds-button--icon add-to-cart-cta"
    >
              
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--m ds-button__icon ds-button__icon--spacing-s" aria-hidden="true">
      <use xlink:href="#i127" />
    </svg>
        </button>
  </form>

      
      </div>
    </div>
          <div class="ds-product-card-refonte__promotion main-vertical--promotion">
                                                  <div class="promotion-description-container">
      <div class="promotion-description">
        <div class="promotion-description__labels">
                      <div class=" promotion-label-refonte promotion-label-refonte__size-s promotion-label-refonte__promo">
      
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--s svg-icon--margin-right" aria-hidden="true">
      <use xlink:href="#i54" />
    </svg>
                        <span class="promotion-label-refonte__label">
        Vu en catalogue
      </span>
      </div>
                  </div>
      </div>
    </div>
        
      </div>
        <div class="main-vertical--infos-product">
      <div class="main-vertical--title">
                <div class="ds-product-card-refonte__title ds-product-card-refonte__shimzone--large">
          
<a
  href="/p/rhum-royal-ambre-agricole-saint-james-3255537503075"
  title="Rhum Royal Ambré agricole SAINT JAMES"
  rel=""
  target=""
  class="product-card-title product-card-title__reduced-line-clamp"
>
  

      

<h2 class="ds-title ds-title--s ds-title--medium">
  Rhum Royal Ambré agricole SAINT JAMES
</h2>
</a>
        </div>
      
      </div>
      
      <div class="main-vertical--infos">
                <div class="ds-format">
  70cL
</div>      
                

    

<div class="ds-body-text ds-body-text--size-s ds-body-text--color-standard-3 product-card-per-unit-label">
      22.21 € / L
  </div>
      
      </div>
              <div class="main-vertical--rating">
          <div class="users-rating">
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g100.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__full" aria-hidden="true" alt="" />
                      


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
            


      <img src="/images/design-system/graphic/g99.svg" class="svg-base svg-graphic svg-icon--m users-rating-star users-rating-star__empty" aria-hidden="true" alt="" />
              <span class="users-rating-count">&#40;128&#41;</span>
  </div>

        </div>
                </div>
          </div>
</article>
</div>
            </li>

        
        <!--  GAM -->
        <li class="product-grid-item fullwidth">
                
<div
  is="AdTag"
  id="gam_banner-plp"
  class="product-list__google-banner1"
>
  <div class="ad-tag__inner"></div>
</div>
          </li>

      </ul>

          <div class="pagination" is="pagination">
      <footer id="data-voir-plus" class="pagination__bottom">
      <p class="pagination__txt">
        Vous consultez 1 des 10 produits
      </p>
      <div class="pagination__bar-bg">
                <div class="pagination__bar" style="width: 10%"></div>
      </div>
            <div class="pagination__button-wrap">
        <a class="a-button button-link is-secondary"
   href="/s?q=rhum&amp;noRedirect=0&amp;page=2"
      >
   Produits suivants
</a>
      </div>
          </footer>
  </div>
    </div>
  
    
    
<div
    is="product-substitution"
    class="product-substitution"
    :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
</div>

      <div
    is="promotion-mixable"
    class="promotion-mixable"
    :render-context="{&quot;zone&quot;:&quot;search-results&quot;}"
>
</div>

  
  <div class="product-listing-page__advertising-placeholder-digital-panel">
    <div
      is="advertising-placeholder"
      placement-name="bottomCd"
    />
  </div>
      </section>
      <aside class="side-template__flapnav">
                  <label class="side-template__flapnav-close" for="flapnav-checkbox">Annuler</label>
              </aside>
    </div>
  
    <aside class="svg-icons-sprite">
    <svg aria-hidden="true" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
        <defs>
            <symbol id="icon-cart" viewBox="0 0 24 24" aria-hidden="true">
  <path d="M22.9,5.6c-0.2-0.2-0.5-0.4-0.8-0.4H7.2c-0.1,0-0.2,0-0.2,0l-0.6-2C6.3,3,6.1,2.7,5.8,2.6L1.7,1.1C1.2,0.9,0.6,1.1,0.4,1.7
    C0.2,2.2,0.5,2.8,1,2.9l3.6,1.4l3.3,11.3c0.1,0.4,0.5,0.7,1,0.7H20c0.5,0,0.9-0.3,1-0.8l2.1-9.1C23.1,6.2,23,5.9,22.9,5.6z
     M16.5,7.2l-1.3,7.1h-1.5l-1.2-7.1H16.5z M7.5,7.2H11l1.2,7.1H9.6L7.5,7.2z M19.2,14.3h-2.4L18,7.2h2.8L19.2,14.3z"/>
  <g>
    <circle cx="10.9" cy="20.4" r="2"/>
  </g>
  <g>
    <circle cx="18.1" cy="20.4" r="2"/>
  </g>
</symbol>
            <symbol id="icon-plus" viewBox="0 0 24 24" aria-hidden="true">
<path d="M18.7,10.7h-5.3V5.4c0-0.6-0.5-1.1-1.1-1.1s-1.1,0.5-1.1,1.1v5.3H5.8c-0.6,0-1.1,0.5-1.1,1.1S5.1,13,5.8,13h5.3v5.3
	c0,0.6,0.5,1.1,1.1,1.1s1.1-0.5,1.1-1.1V13h5.3c0.6,0,1.1-0.5,1.1-1.1S19.3,10.7,18.7,10.7z"/>
</symbol>
            <symbol id="icon-minus" viewBox="0 0 24 24" aria-hidden="true">
  <path d="M16.7,10.7h-9c-0.6,0-1.1,0.5-1.1,1.1S7.1,13,7.8,13h9c0.6,0,1.1-0.5,1.1-1.1S17.3,10.7,16.7,10.7z"/>
</symbol>
            <symbol id="icon-sad" viewBox="0 0 24 24" aria-hidden="true">
  <path d="M12,2c5.5,0,10,4.5,10,10c0,5.5-4.5,10-10,10S2,17.5,2,12C2,6.5,6.4,
  2,12,2 M12,0C5.3,0,0,5.4,0,12c0,6.6,5.4,12,12,12
    s12-5.4,12-12C24,5.4,18.6,0,12,0L12,0z"/>
  <g>
    <path d="M17.6,16.8c-0.2,0-0.4-0.1-0.5-0.2c-1.3-1.3-3-2-4.8-2s-3.5,0.7-4.8,2c-0.3,0.3-0.8,0.3-1.1,0s-0.3-0.8,0-1.1
      C8,14,10,13.1,12.3,13.1c2.2,0,4.3,0.9,5.9,2.4c0.3,0.3,0.3,0.8,0,1.1C18,16.8,17.8,16.8,17.6,16.8z"/>
  </g>
  <circle cx="8.4" cy="9.7" r="1.3"/>
  <circle cx="15.5" cy="9.7" r="1.3"/>
</symbol>
            <symbol id="icon-left" viewBox="0 0 24 24" aria-hidden="true">
  <g class="icon-left" transform="rotate(-180 12,11.999999046325684)">
    <path d="m16.099832,3.936998c-0.32213,-0.333393 -0.858261,
    -0.333393 -1.191654,0c-0.32213,0.32213 -0.32213,0.858261 0,1.17964l6.04237,6.04237l-19.938996,
    0c-0.464798,0.000751 -0.834233,0.370186 -0.834233,0.834984c0,0.464798 0.369435,0.846247 0.834233,
    0.846247l19.938996,0l-6.04237,6.031107c-0.32213,0.333393 -0.32213,0.870276 0,1.191654c0.333393,
    0.333393 0.870276,0.333393 1.191654,0l7.472806,-7.472806c0.333393,-0.32213 0.333393,-0.858261 0,
    -1.17964l-7.472806,-7.473557z"/>
  </g>
</symbol>
            <symbol id="icon-right" viewBox="0 0 24 24" aria-hidden="true">
  <g class="icon-right">
    <path d="m16.099832,3.936998c-0.32213,-0.333393 -0.858261,-0.333393 -1.191654,0c-0.32213,0.32213 -0.32213,
    0.858261 0,1.17964l6.04237,6.04237l-19.938996,0c-0.464798,0.000751 -0.834233,0.370186 -0.834233,0.834984c0,
    0.464798 0.369435,0.846247 0.834233,0.846247l19.938996,0l-6.04237,6.031107c-0.32213,0.333393 -0.32213,
    0.870276 0,1.191654c0.333393,0.333393 0.870276,0.333393 1.191654,0l7.472806,-7.472806c0.333393,-0.32213 0.333393,
    -0.858261 0,-1.17964l-7.472806,-7.473557z"/>
  </g>
</symbol>
            <symbol id="icon-shopping-list" viewBox="0 0 24 24" aria-hidden="true">
  <g id="Page-1" class="icon-shopping-list-graphic">
    <path d="M15.94,9S16,9,16,9V1a1,1,0,0,0-1-1H2A1,1,0,0,0,1,1v15.1a1,1,0,0,0,1,1H7.49a7.49,7.49,0,1,0,8.45-8Zm-13,6V2H14V9S14,9,14,9a7.53,7.53,0,0,0-4.51,2.36H7.77a.75.75,0,0,0,0,1.5h.6a7.4,7.4,0,0,0-.78,2.17ZM15,22a5.5,5.5,0,1,1,5.5-5.5A5.51,5.51,0,0,1,15,22Z"/>
    <path d="M7.77,5.62h4a.75.75,0,0,0,0-1.5h-4a.75.75,0,0,0,0,1.5Z"/>
    <path d="M7.77,9.26h4a.75.75,0,0,0,0-1.5h-4a.75.75,0,0,0,0,1.5Z"/>
    <path d="M17.55,15.71H15.7V14a.75.75,0,0,0-1.5,0v1.75H12.45a.75.75,0,0,0,0,1.5H14.2v1.85a.75.75,0,0,0,1.5,0V17.21h1.85a.75.75,0,1,0,0-1.5Z"/>
    <path d="M4.6,11.6a.78.78,0,1,0,1.1,0A.78.78,0,0,0,4.6,11.6Z"/>
    <path d="M4.6,8A.78.78,0,1,0,5.7,9.1.9.9,0,0,0,5.7,8,.78.78,0,0,0,4.6,8Z"/>
    <path d="M4.6,4.3a.78.78,0,1,0,1.1,0A.78.78,0,0,0,4.6,4.3Z"/>
  </g>
</symbol>
            <symbol id="icon-cross" viewBox="0 0 24 24" aria-hidden="true">
    <path class="icon-cross" d="M18.9,5.3c-0.4-0.4-1.2-0.4-1.6,0l-5,5l-5-5c-0.4-0.4-1.2-0.4-1.6,0c-0.4,0.4-0.4,1.2,0,1.6l5,5l-5,5
    	c-0.4,0.4-0.4,1.2,0,1.6c0.2,0.2,0.5,0.3,0.8,0.3s0.6-0.1,0.8-0.3l5-5l5,5c0.2,0.2,0.5,0.3,0.8,0.3s0.6-0.1,0.8-0.3
    	c0.4-0.4,0.4-1.2,0-1.6l-5-5l5-5C19.3,6.5,19.3,5.8,18.9,5.3z"/>
</symbol>
            <symbol id="icon-info" viewBox="0 0 24 24" aria-hidden="true">
    <path id="a" d="M11 22C4.925 22 0 17.075 0 11S4.925 0 11 0s11 4.925 11 11-4.925 11-11 11zm0-2a9 9 0 1 0 0-18 9 9 0 0 0 0 18zm1-5a1 1 0 0 1-2 0v-4a1 1 0 0 1 2 0v4zm-1.707-6.293a1 1 0 1 1 1.414-1.414 1 1 0 0 1-1.414 1.414z"/>
</symbol>
            <symbol id="icon-promo" viewBox="0 0 16 16" aria-hidden="true">
    <g class="icon-promo" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd">
        <path d="M13.1517246,9.42725547 C12.980837,9.56162019 12.9086694,9.79480342 12.9713055,10.0080808 L13.6616641,12.2730862 L11.363192,12.3171635 C11.1473698,12.3192962 10.9560574,12.4636139 10.8866131,12.6768913 L10.1717447,14.9347874 L8.2926621,13.5591485 C8.1163279,13.4304712 7.88280423,13.4304712 7.70715086,13.5591485 L5.85530133,14.9461622 L5.1063916,12.6768913 C5.03694724,12.4650358 4.84767732,12.321429 4.63321681,12.3171635 L2.35653122,12.3043668 L3.02510336,10.0080808 C3.08773945,9.79480342 3.01557178,9.56162019 2.8446842,9.42725547 L1.01257866,8.01891408 L2.84604585,6.57147184 C3.01693344,6.43639619 3.0891011,6.20463481 3.02646502,5.99064654 L2.33610641,3.72493024 L4.63457846,3.68085292 C4.84767732,3.67800922 5.03694724,3.53582432 5.10775325,3.32539068 L5.82262163,1.06749454 L7.70715086,2.44100063 C7.88280423,2.56967796 8.1163279,2.56967796 8.2926621,2.44100063 L10.1445116,1.05256512 L10.8934214,3.32254698 C10.9649082,3.53369155 11.1548589,3.67587645 11.3700003,3.67800922 L13.6473667,3.69080586 L12.9781137,5.98709192 C12.9154776,6.20108019 12.9876453,6.43284157 13.1585329,6.56862814 L14.9681711,7.9961645 L13.1517246,9.42725547 Z M15.6027019,7.16793748 L14.0538204,5.9458583 L14.6189069,4.00503448 C14.7795821,3.45406801 14.4820606,2.87110994 13.9544197,2.70333176 C13.866593,2.67560571 13.776043,2.66067629 13.6848122,2.65854352 L11.7437743,2.62228637 L11.1106052,0.703501206 C10.930186,0.158222132 10.3610146,-0.130413206 9.83950112,0.0572708565 C9.7509936,0.0892624579 9.66725188,0.1340507 9.59099925,0.190213734 L7.99990648,1.35328618 L6.40881371,0.190213734 C5.95606373,-0.139655224 5.333107,-0.0244854584 5.01720326,0.448279319 C4.96409875,0.526481012 4.92188747,0.613924722 4.89193108,0.704212131 L4.25876194,2.62370822 L2.31500077,2.65854352 C1.76285005,2.67134016 1.32507826,3.14837048 1.33733315,3.72493024 C1.33937563,3.81948319 1.353673,3.91403615 1.38022525,4.00503448 L1.94531169,5.9458583 L0.397111021,7.16722655 C-0.0433840686,7.51486862 -0.130529929,8.16820822 0.201713663,8.62817636 C0.258222306,8.7049562 0.323581701,8.77320495 0.397111021,8.83150076 L1.94531169,10.0535799 L1.38022525,11.9936928 C1.21955007,12.5453702 1.51843314,13.1283283 2.04607409,13.2953955 C2.13321995,13.3231216 2.22376995,13.338051 2.31500077,13.3401838 L4.25603863,13.3771519 L4.88920777,15.296648 C5.06962694,15.8412161 5.63947916,16.1312733 6.16099267,15.9421674 C6.24813853,15.9108867 6.3305186,15.8675203 6.4060904,15.8120682 L7.99990648,14.646863 L9.59236091,15.8106464 C10.0451109,16.1398044 10.6673868,16.0239237 10.9826097,15.5511589 C11.0357142,15.4722463 11.0779255,15.3862244 11.1078819,15.2945152 L11.741051,13.3750191 L13.6820889,13.3373401 C14.232878,13.3266762 14.6720114,12.8517787 14.661799,12.2766408 C14.6604373,12.179955 14.6454591,12.0839802 14.6189069,11.9915601 L14.0538204,10.0514472 L15.6033828,8.82865706 C16.043197,8.48243684 16.1303429,7.82909724 15.7987801,7.36984003 C15.7429523,7.29306019 15.6769121,7.22410051 15.6033828,7.16580471 L15.6027019,7.16793748 Z M5.3660428,6.25466653 C5.36953953,5.8897821 5.65557206,5.59641501 6.00524508,5.59787455 C6.35561744,5.60079362 6.63675455,5.89926909 6.63465651,6.26415353 C6.61647352,6.62174027 6.34023183,6.9070799 5.99685293,6.92094551 C5.64648056,6.91802643 5.36464411,6.62028073 5.3660428,6.25466653 L5.3660428,6.25466653 Z M6.00034966,7.65217391 C6.73256496,7.65071438 7.32700909,7.03478945 7.33330321,6.27072144 C7.33819863,5.50227483 6.74585253,4.8746736 6.00944115,4.86956522 L6.00034966,4.86956522 C5.26813435,4.87102476 4.67369022,5.48549014 4.66669676,6.24955815 C4.66180134,7.01800477 5.25484678,7.64560599 5.99125816,7.65217391 L6.00034966,7.65217391 Z M9.77931965,10.2065127 C9.52964352,10.4640737 9.12820345,10.4611552 8.88202418,10.2006756 C8.6358449,9.94092569 8.6386424,9.52211541 8.88831853,9.26455438 C9.1372953,9.00772299 9.53873536,9.01064153 9.78491464,9.2711211 C9.78491464,9.2711211 9.78561401,9.2711211 9.78561401,9.27185073 C10.0317933,9.53160066 10.0289958,9.95114058 9.77931965,10.207972 C9.77931965,10.2087016 9.77931965,10.2087016 9.77931965,10.2087016 L9.77931965,10.2065127 Z M8.39735873,8.74724343 C8.92118906,8.2095027 9.76393345,8.21533978 10.28077,8.76110648 C10.7990054,9.30760283 10.7948092,10.1882718 10.2709788,10.7282015 C9.7471485,11.2688607 8.90300537,11.2637533 8.38477002,10.7172569 C7.86723405,10.1693013 7.87212966,9.28790269 8.39735873,8.74724343 Z M10.5279533,4.93946761 C10.6834276,5.05161987 10.7125347,5.26057022 10.5932667,5.40743628 L5.97305405,10.9950223 C5.97021433,10.9996953 5.96666469,11.0030332 5.96382498,11.0070386 C5.83958755,11.1505668 5.61667009,11.1719292 5.46403553,11.0551039 C5.3121109,10.9389462 5.2893932,10.7286607 5.4129207,10.5858001 L10.0310036,4.99821403 C10.1509815,4.85335069 10.373189,4.82664777 10.5279533,4.93946761 Z" id="Fill-115" fill="#ffffff"></path>
    </g>
</symbol>            <symbol id="icon-coupon" viewBox="0 0 16 16" >
    <g class="icon-coupon" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd">
        <path d="M0.698794442,6.82930645 L0.698794442,4.1352725 C0.69814431,3.24946939 1.40353682,2.52888756 2.27146216,2.52888756 L13.7261263,2.52888756 C14.1402599,2.51441562 14.5595947,2.70375679 14.8586551,3.02153639 C15.1427625,3.32243207 15.298794,3.71799833 15.298794,4.1352725 L15.298794,6.86441809 C14.7581825,7.13113049 14.386294,7.68786754 14.386294,8.33146381 C14.386294,8.97506007 14.7581825,9.53179713 15.298794,9.79850953 L15.298794,11.8717285 C15.298794,12.7575316 14.5940516,13.4781135 13.7261263,13.4781135 L2.27081203,13.4781135 L2.26366058,13.4781135 C1.83587416,13.4763045 1.43734365,13.3014352 1.13893336,12.9860676 C0.854175832,12.6845689 0.698794442,12.2890027 0.698794442,11.8717285 L0.698794442,9.83362117 C1.28026659,9.58308878 1.68733566,9.00481433 1.68733566,8.33146381 C1.68733566,7.65811328 1.28026659,7.07983883 0.698794442,6.82930645 Z M6.34747793,6.97362745 L5.71754399,6.97362745 L5.71754399,7.66370557 L6.23972607,7.66370557 C6.23420031,7.70088168 6.23143747,7.74038071 6.23143747,7.78220383 L6.23143747,7.9982889 C6.23143747,8.02617099 6.23420031,8.06567001 6.23972607,8.11678717 L5.71754399,8.11678717 L5.71754399,8.80686529 L6.31432351,8.80686529 C6.43036456,9.31803683 6.67073168,9.71418883 7.0354321,9.99533317 C7.40013252,10.2764775 7.92783506,10.4170476 8.61855555,10.4170476 C8.9335241,10.4170476 9.20842673,10.3926511 9.4432717,10.3438575 C9.67811666,10.2950638 9.87013408,10.2381388 10.0193297,10.1730806 L9.77896018,9.37147467 C9.5910842,9.43653286 9.40321105,9.48300231 9.21533507,9.51088439 C9.0274591,9.53876647 8.84234879,9.55270731 8.65999858,9.55270731 C8.37818461,9.55270731 8.14334317,9.49810571 7.9554672,9.38890088 C7.76759122,9.27969605 7.62668636,9.08568613 7.53274837,8.80686529 L8.95838834,8.80686529 L9.11587182,8.11678717 L7.42499651,8.11678717 C7.41947075,8.06567001 7.41670791,8.02617099 7.41670791,7.9982889 L7.41670791,7.79265956 C7.41670791,7.75780696 7.41947075,7.71482272 7.42499651,7.66370557 L9.21533507,7.66370557 L9.37281856,6.97362745 L7.53274837,6.97362745 C7.61563483,6.73662973 7.74963259,6.55772238 7.93474569,6.43690002 C8.11985878,6.31607765 8.37818437,6.25566738 8.7097302,6.25566738 C8.91418347,6.25566738 9.08547958,6.26844647 9.22362368,6.29400505 C9.36176778,6.31956363 9.49714696,6.3509305 9.6297653,6.38810661 L9.88671204,5.57953022 C9.70988759,5.52376606 9.5330658,5.47962009 9.35624135,5.44709099 C9.1794169,5.41456189 8.96667818,5.39829758 8.71801881,5.39829758 C8.08808172,5.39829758 7.57143054,5.5307355 7.16804977,5.79561529 C6.76466901,6.06049509 6.49114779,6.45316188 6.34747793,6.97362745 Z" id="Combined-" fill="#fff78f" transform="translate(7.998794, 8.003113) rotate(-12.000000) translate(-7.998794, -8.003113) "></path>
    </g>
</symbol>
            <symbol id="icon-carrefour-loyalty-card" viewBox="0 0 16 16">
    <g class="icon-carrefour-loyalty-card" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd">
        <path d="M2.26366058,13.4831135 C1.83587416,13.4813045 1.43734365,13.3064352 1.13893336,12.9910676 C0.854175832,12.6895689 0.698794442,12.2940027 0.698794442,11.8767285 L0.698794442,4.1402725 C0.69814431,3.25446939 1.40353682,2.53388756 2.27146216,2.53388756 L13.7261263,2.53388756 C14.1402599,2.51941562 14.5595947,2.70875679 14.8586551,3.02653639 C15.1427625,3.32743207 15.298794,3.72299833 15.298794,4.1402725 L15.298794,11.8767285 C15.298794,12.7625316 14.5940516,13.4831135 13.7261263,13.4831135 L2.27081203,13.4831135 L2.26366058,13.4831135 Z M6.26877405,5.45056981 L4.07133011,7.5764993 C3.96210805,7.66946808 3.89254399,7.77869015 3.89254399,7.9353718 C3.89254399,8.09140332 3.96210805,8.20062539 4.07133011,8.29489443 L6.26877405,10.4195237 C6.28307694,10.4344767 6.2967297,10.4396777 6.30843206,10.4396777 C6.32923626,10.4396777 6.34353915,10.4208239 6.34288902,10.3987195 C6.34223889,10.3857168 6.33638771,10.3707638 6.32338508,10.3577612 C5.80783093,9.71673168 5.43270514,8.98208326 5.43270514,7.94252325 C5.43270514,6.90296323 5.80783093,6.15401192 6.32338508,5.51233229 C6.33638771,5.49997979 6.34223889,5.48502677 6.34288902,5.47137402 C6.34353915,5.44926955 6.32923626,5.43041574 6.30843206,5.43041574 C6.2967297,5.43041574 6.28307694,5.43626692 6.26877405,5.45056981 Z M7.95827037,5.27061346 C7.0981466,5.27061346 6.76137857,6.48960972 6.76137857,7.94265327 C6.76137857,9.39634695 7.0981466,10.5997401 7.95827037,10.5997401 C8.47447465,10.5997401 8.91461357,10.2967789 8.91591383,10.0484287 C8.91656397,9.99446779 8.89510963,9.94245728 8.84960044,9.89694809 C8.60515105,9.66030028 8.50958175,9.4243026 8.50828148,9.21561044 C8.50698122,8.81773006 8.85220096,8.52127017 9.17011519,8.52127017 C9.60830371,8.52127017 9.86640586,8.86518965 9.86640586,9.31052962 C9.86640586,9.73246486 9.68631947,10.0841859 9.49062994,10.3650427 C9.4834785,10.3773951 9.47957771,10.3897476 9.47957771,10.4007999 C9.48022784,10.4229043 9.49258033,10.441108 9.51273441,10.441108 C9.52378664,10.441108 9.53808953,10.4352568 9.55304255,10.4196537 L11.7511366,8.29502446 C11.8603587,8.20075542 11.9305729,8.09153335 11.9305729,7.93550183 C11.9305729,7.77882018 11.8603587,7.66959811 11.7511366,7.5759792 L9.55304255,5.45069984 C9.53808953,5.43574682 9.52378664,5.4292455 9.51273441,5.4292455 C9.49258033,5.4292455 9.48022784,5.44744918 9.47957771,5.46955365 C9.47957771,5.48060588 9.4834785,5.49360851 9.49062994,5.50531087 C9.68631947,5.78616761 9.86640586,6.1385388 9.86640586,6.55982391 C9.86640586,7.00516388 9.60830371,7.34973349 9.17011519,7.34973349 C8.85220096,7.34973349 8.50698122,7.0532736 8.50828148,6.65474308 C8.50958175,6.44670105 8.60515105,6.21005325 8.84960044,5.97405557 C8.89510963,5.92789624 8.91656397,5.87653587 8.91591383,5.82192484 C8.91461357,5.57292453 8.47447465,5.27061346 7.95827037,5.27061346 Z" id="Combined-Shape" fill="#0e3368" transform="translate(7.998794, 8.008113) rotate(-12.000000) translate(-7.998794, -8.008113) "></path>
    </g>
</symbol>            <symbol id="icon-carrefour-loyalty-card-hightlighted" viewBox="0 0 16 16">
    <g class="icon-carrefour-loyalty-card-hightlighted" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd">
        <path d="M2.26366058,13.4831135 C1.83587416,13.4813045 1.43734365,13.3064352 1.13893336,12.9910676 C0.854175832,12.6895689 0.698794442,12.2940027 0.698794442,11.8767285 L0.698794442,4.1402725 C0.69814431,3.25446939 1.40353682,2.53388756 2.27146216,2.53388756 L13.7261263,2.53388756 C14.1402599,2.51941562 14.5595947,2.70875679 14.8586551,3.02653639 C15.1427625,3.32743207 15.298794,3.72299833 15.298794,4.1402725 L15.298794,11.8767285 C15.298794,12.7625316 14.5940516,13.4831135 13.7261263,13.4831135 L2.27081203,13.4831135 L2.26366058,13.4831135 Z M6.26877405,5.45056981 L4.07133011,7.5764993 C3.96210805,7.66946808 3.89254399,7.77869015 3.89254399,7.9353718 C3.89254399,8.09140332 3.96210805,8.20062539 4.07133011,8.29489443 L6.26877405,10.4195237 C6.28307694,10.4344767 6.2967297,10.4396777 6.30843206,10.4396777 C6.32923626,10.4396777 6.34353915,10.4208239 6.34288902,10.3987195 C6.34223889,10.3857168 6.33638771,10.3707638 6.32338508,10.3577612 C5.80783093,9.71673168 5.43270514,8.98208326 5.43270514,7.94252325 C5.43270514,6.90296323 5.80783093,6.15401192 6.32338508,5.51233229 C6.33638771,5.49997979 6.34223889,5.48502677 6.34288902,5.47137402 C6.34353915,5.44926955 6.32923626,5.43041574 6.30843206,5.43041574 C6.2967297,5.43041574 6.28307694,5.43626692 6.26877405,5.45056981 Z M7.95827037,5.27061346 C7.0981466,5.27061346 6.76137857,6.48960972 6.76137857,7.94265327 C6.76137857,9.39634695 7.0981466,10.5997401 7.95827037,10.5997401 C8.47447465,10.5997401 8.91461357,10.2967789 8.91591383,10.0484287 C8.91656397,9.99446779 8.89510963,9.94245728 8.84960044,9.89694809 C8.60515105,9.66030028 8.50958175,9.4243026 8.50828148,9.21561044 C8.50698122,8.81773006 8.85220096,8.52127017 9.17011519,8.52127017 C9.60830371,8.52127017 9.86640586,8.86518965 9.86640586,9.31052962 C9.86640586,9.73246486 9.68631947,10.0841859 9.49062994,10.3650427 C9.4834785,10.3773951 9.47957771,10.3897476 9.47957771,10.4007999 C9.48022784,10.4229043 9.49258033,10.441108 9.51273441,10.441108 C9.52378664,10.441108 9.53808953,10.4352568 9.55304255,10.4196537 L11.7511366,8.29502446 C11.8603587,8.20075542 11.9305729,8.09153335 11.9305729,7.93550183 C11.9305729,7.77882018 11.8603587,7.66959811 11.7511366,7.5759792 L9.55304255,5.45069984 C9.53808953,5.43574682 9.52378664,5.4292455 9.51273441,5.4292455 C9.49258033,5.4292455 9.48022784,5.44744918 9.47957771,5.46955365 C9.47957771,5.48060588 9.4834785,5.49360851 9.49062994,5.50531087 C9.68631947,5.78616761 9.86640586,6.1385388 9.86640586,6.55982391 C9.86640586,7.00516388 9.60830371,7.34973349 9.17011519,7.34973349 C8.85220096,7.34973349 8.50698122,7.0532736 8.50828148,6.65474308 C8.50958175,6.44670105 8.60515105,6.21005325 8.84960044,5.97405557 C8.89510963,5.92789624 8.91656397,5.87653587 8.91591383,5.82192484 C8.91461357,5.57292453 8.47447465,5.27061346 7.95827037,5.27061346 Z" id="Combined-Shape" fill="#c4efff" transform="translate(7.998794, 8.008113) rotate(-12.000000) translate(-7.998794, -8.008113) "></path>
    </g>
</symbol>        </defs>
    </svg>
</aside>
  </div>
  
<div
    is="advertising-loader"
    :context="&quot;search-results&quot;"
    :breadcrumb="[]"
    :current-page="1"
    :transaction-id="&quot;&quot;"
    :recommendation-vars="null"
></div>

    </main>

  <div id="overlay"></div>

  <div id="colophon">
                            <div class="footer-aside footer-aside--accent">
            




<div is="FooterReassuranceBanner" class="footer-reassurance-banner" :is-non-food="false" >
      <ul class="footer-reassurance-banner__list  footer-reassurance-banner__grid footer-reassurance-banner__food">
          <li class="footer-reassurance-banner__list-item">
        


      <img src="/images/design-system/graphic/g103.svg" class="svg-base svg-graphic svg-icon--m footer-reassurance-banner__icon" aria-hidden="true" alt="" />
          
                      
   
<a class="pl-link pl-link--size-m pl-link--tone-primary footer-reassurance-banner__link"
   href="/magasin"    target="_self"     >
      Rechercher un magasin
  </a>
                </li>
          <li class="footer-reassurance-banner__list-item">
        


      <img src="/images/design-system/graphic/g114.svg" class="svg-base svg-graphic svg-icon--m footer-reassurance-banner__icon" aria-hidden="true" alt="" />
          
                      
   
<a class="pl-link pl-link--size-m pl-link--tone-primary footer-reassurance-banner__link"
   href="/services/nous-contacter"    target="_self"     >
      Obtenir de l&#039;aide
  </a>
                </li>
          <li class="footer-reassurance-banner__list-item">
        


      <img src="/images/design-system/graphic/g106.svg" class="svg-base svg-graphic svg-icon--m footer-reassurance-banner__icon" aria-hidden="true" alt="" />
          
                      
   
<a class="pl-link pl-link--size-m pl-link--tone-primary footer-reassurance-banner__link"
   href="https://carrefour.onelink.me/1251175874/gc5848d7"    target="_self"     >
      Télécharger l&#039;application
  </a>
                </li>
        </ul>
    
</div>          </div>
                      <div class="footer-aside">
              

<div is="FooterPartnerBanner" class="footer-partner-banner">
  <a class="footer-partner-banner__wrapper" href="https://www.carrefour.com/fr/news/paris2024cp" target="_blank">
      <div class="footer-partner-banner__logos">
        


      <img src="/images/design-system/brand/b35.svg" class="svg-base svg-brand footer-partner-banner__logo" aria-hidden="true" alt="" />
          


      <img src="/images/design-system/brand/b37.svg" class="svg-base svg-brand footer-partner-banner__logo" aria-hidden="true" alt="" />
          


      <img src="/images/design-system/brand/b34.svg" class="svg-base svg-brand footer-partner-banner__logo" aria-hidden="true" alt="" />
        </div>
      <div class="footer-partner-banner__text">
        Partenaires courses alimentaires des jeux Olympiques et Paralympiques 2024 !
      </div>
    </a>
</div>
            </div>
                    
<footer
  is="MainFooter"
  class="main-footer"
  :footer-attributes="[{&quot;title&quot;:&quot;En ce moment&quot;,&quot;children&quot;:[{&quot;title&quot;:&quot;Promotions&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/promotions&quot;}},{&quot;title&quot;:&quot;Primes Fid\u00e9lit\u00e9&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/carte-carrefour\/primes&quot;}},{&quot;title&quot;:&quot;Jouets de No\u00ebl&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/r\/jeux-jouets&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Sapin de No\u00ebl&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/r\/maison-decoration\/sapins-decorations-noel\/sapin&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Calendrier de l&#039;avent&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/r\/noel\/calendriers-lavent&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Po\u00eales \u00e0 p\u00e9trole&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/r\/bricolage\/chauffage-climatisation\/poeles-petrole-gaz&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;FIFA 24 \/ EA Sports FC 24&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;https:\/\/www.carrefour.fr\/jeux-consoles\/fifa-24&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Call of Duty MWIII&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/jeux-consoles\/call-of-duty-modern-warfare-3&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Lit Parapluie&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/r\/bebe\/voyage\/lits-parapluies&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;PlayStation 5&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/r\/jeux-videos-culture\/playstation-5&quot;,&quot;target&quot;:&quot;_self&quot;}}]},{&quot;title&quot;:&quot;Nos services&quot;,&quot;children&quot;:[{&quot;title&quot;:&quot;Carrefour Drive&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/drive&quot;}},{&quot;title&quot;:&quot;Livraison \u00e0 Domicile&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/livraison-domicile&quot;}},{&quot;title&quot;:&quot;Drive Pi\u00e9ton&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/drive\/pieton&quot;}},{&quot;title&quot;:&quot;Livraison Express&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/livraison-express&quot;}},{&quot;title&quot;:&quot;Traiteur en ligne&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/traiteur-en-ligne&quot;}},{&quot;title&quot;:&quot;Carte de Fid\u00e9lit\u00e9&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/carte-carrefour&quot;}},{&quot;title&quot;:&quot;Banque et Assurance&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/banque-et-assurance&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Energies&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/energies&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Location&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/carrefour-location&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Spectacles&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/spectacles&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Voyages&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/voyages&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Tous les services&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services&quot;,&quot;target&quot;:&quot;_self&quot;}}]},{&quot;title&quot;:&quot;Nos enseignes&quot;,&quot;children&quot;:[{&quot;title&quot;:&quot;Hypermarch\u00e9s&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/hyper&quot;}},{&quot;title&quot;:&quot;Carrefour Market&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/market&quot;}},{&quot;title&quot;:&quot;Carrefour City&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/city&quot;}},{&quot;title&quot;:&quot;Carrefour Express&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/express&quot;}},{&quot;title&quot;:&quot;Carrefour Contact&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/contact&quot;}},{&quot;title&quot;:&quot;Carrefour Montagne&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/montagne&quot;}},{&quot;title&quot;:&quot;Bon app&#039;&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes\/bonapp&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Carrefour recrute&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;https:\/\/recrute.carrefour.fr\/&quot;,&quot;target&quot;:&quot;_blank&quot;}},{&quot;title&quot;:&quot;Toutes les enseignes&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/enseignes&quot;}},{&quot;title&quot;:&quot;Tous les magasins&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/magasin\/liste&quot;,&quot;target&quot;:&quot;_self&quot;}}]},{&quot;title&quot;:&quot;Nos offres&quot;,&quot;children&quot;:[{&quot;title&quot;:&quot;Ma Communaut\u00e9&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;http:\/\/communaute.carrefour.fr?utm_source=one&amp;utm_medium=ecosysteme_carrefour&amp;utm_campaign=ECOM_footer_perm_032023&quot;,&quot;target&quot;:&quot;_blank&quot;}},{&quot;title&quot;:&quot;Jeux Concours&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/jeux-concours&quot;}},{&quot;title&quot;:&quot;Campagnes TV&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/evenements\/campagnes-tv&quot;}},{&quot;title&quot;:&quot;Fili\u00e8re Qualit\u00e9 Carrefour&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/marques\/filiere-qualite-carrefour&quot;}},{&quot;title&quot;:&quot;Reflets de France&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/marques\/reflets-de-france&quot;}},{&quot;title&quot;:&quot;Carrefour Baby&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/marques\/baby&quot;}},{&quot;title&quot;:&quot;Carrefour Bio&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/marques\/carrefour-bio&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Toutes nos marques&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/marques&quot;,&quot;target&quot;:&quot;_self&quot;}}]},{&quot;title&quot;:&quot;Vos donn\u00e9es&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/articles\/gestion-donnees-personnelles&quot;},&quot;children&quot;:[{&quot;title&quot;:&quot;Politique sur les cookies&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/cookies&quot;}},{&quot;title&quot;:&quot;Param\u00e9trer vos cookies&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;#show-privacy-center&quot;}},{&quot;title&quot;:&quot;Politique de protection des donn\u00e9es personnelles&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/articles\/politique-generale-protection-donnees-personnelles&quot;,&quot;target&quot;:&quot;_self&quot;}}]},{&quot;title&quot;:&quot;Carrefour.fr&quot;,&quot;children&quot;:[{&quot;title&quot;:&quot;CGV&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/conditions-generales-ventes&quot;}},{&quot;title&quot;:&quot;CGU Marketplace&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/conditions-generales-utilisation-marketplace&quot;}},{&quot;title&quot;:&quot;Mentions l\u00e9gales&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/mentions-legales&quot;}},{&quot;title&quot;:&quot;CG carte Carrefour&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/carte-carrefour\/conditions-generales&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Accessibilit\u00e9 : partiellement conforme&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/engagements\/accessibilite&quot;,&quot;target&quot;:&quot;_self&quot;}}]},{&quot;title&quot;:&quot;Vous informer&quot;,&quot;children&quot;:[{&quot;title&quot;:&quot;Alerte de s\u00e9curit\u00e9&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/securite&quot;}},{&quot;title&quot;:&quot;Pi\u00e8ces d\u00e9tach\u00e9es&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/pieces-detachees&quot;}},{&quot;title&quot;:&quot;Rappel produits&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/rappel-produits&quot;}},{&quot;title&quot;:&quot;Qualit\u00e9s et Caract\u00e9ristiques Environnementales&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/engagements\/qualites-caracteristiques-environnementales&quot;,&quot;target&quot;:&quot;_self&quot;}},{&quot;title&quot;:&quot;Aide &amp; Contact&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/nous-contacter&quot;}},{&quot;title&quot;:&quot;Acc\u00e8s malentendants&quot;,&quot;link&quot;:{&quot;uri&quot;:&quot;\/services\/accessibilite-sourds-et-malentendants&quot;}}]}]"
>
  <section class ="main-footer__section">
    <div class="main-footer__container main-footer__container--main">
              <ul class="main-footer__list main-footer__list--main">
                      <li class="main-footer__item">
              <button class="main-footer__head">
                <strong class="main-footer__heading">En ce moment</strong>
                
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--color-interactive-1 svg-icon--s main-footer__icon main-footer__icon--mobile" aria-hidden="true">
      <use xlink:href="#i02" />
    </svg>
                </button>
                              <ul class="main-footer__list main-footer__list--second">
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/promotions">Promotions</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/carte-carrefour/primes">Primes Fidélité</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/r/jeux-jouets">Jouets de Noël</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/r/maison-decoration/sapins-decorations-noel/sapin">Sapin de Noël</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/r/noel/calendriers-lavent">Calendrier de l&#039;avent</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/r/bricolage/chauffage-climatisation/poeles-petrole-gaz">Poêles à pétrole</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="https://www.carrefour.fr/jeux-consoles/fifa-24">FIFA 24 / EA Sports FC 24</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/jeux-consoles/call-of-duty-modern-warfare-3">Call of Duty MWIII</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/r/bebe/voyage/lits-parapluies">Lit Parapluie</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/r/jeux-videos-culture/playstation-5">PlayStation 5</a>
                    </li>
                                  </ul>
                          </li>
                      <li class="main-footer__item">
              <button class="main-footer__head">
                <strong class="main-footer__heading">Nos services</strong>
                
<script type="application/javascript">
  setTimeout(() => {
    window.ONECF.sprites && window.ONECF.sprites.checkOrFetchDefs({
      prefix: "i",
      source: null,
      isLoaded: false
    })
  }, 0)
</script>


      <svg class="svg-icon svg-icon--color-interactive-1 svg-icon--s main-footer__icon main-footer__icon--mobile" aria-hidden="true">
      <use xlink:href="#i02" />
    </svg>
                </button>
                              <ul class="main-footer__list main-footer__list--second">
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/drive">Carrefour Drive</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/livraison-domicile">Livraison à Domicile</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/drive/pieton">Drive Piéton</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/livraison-express">Livraison Express</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/traiteur-en-ligne">Traiteur en ligne</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/carte-carrefour">Carte de Fidélité</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/banque-et-assurance">Banque et Assurance</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/energies">Energies</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/carrefour-location">Location</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/spectacles">Spectacles</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services/voyages">Voyages</a>
                    </li>
                                      <li class="main-footer__item">
                      <a class="main-footer__link" href="/services">Tous les services</a>
                    </li>
                                  </ul>
                          </li>
                      <li class="main-footer__item">
              <button class="main-footer__head">
                <strong class="main-footer__heading">Nos enseignes</strong>
"""

soup = BeautifulSoup(html_content, 'html.parser')

# Sélectionnez tous les articles de produits
articles = soup.find_all('article', class_='ds-product-card-refonte')

for article in articles:
    # Récupérez le nom du produit
    product_name = article.find('h2', class_='ds-title').text.strip()

    # Récupérez le prix du produit
    product_price = article.find('span', class_='product-price__amount-value').text.strip()

    # Récupérez la promotion du produit s'il y en a une
    promotion = article.find('span', class_='promotion-label-refonte__label')
    promotion_text = promotion.text.strip() if promotion else None

    # Affichez les résultats
    print(f"Nom du produit: {product_name}")
    print(f"Prix: {product_price} €")
    print(f"Promotion: {promotion_text}" if promotion_text else "")
    print("\n")
# Out:
# Nom du produit: Rhum blanc traditionnel OLD NICK
# Prix: 9,95 €
# Promotion: 30% d'économies
#
#
# Nom du produit: Rhum blanc CHARRETTE
# Prix: 15,69 €
# Promotion: 1 acheté = 2€ de remise
#
#
# Nom du produit: Rhum arrangé banane flambée ISAUTIER
# Prix: 14,53 €
# Promotion: 1 acheté = 10% de remise
#
#
# Nom du produit: Rhum arrangé de Noël ISAUTIER
# Prix: 14,53 €
# Promotion: 1 acheté = 10% de remise
#
#
# Nom du produit: Rhum Black Spiced THE KRAKEN
# Prix: 27,49 €
# Promotion: 1 acheté = 4€ de remise
#
#
# Nom du produit: Rhum arrangé coco banane ISAUTIER
# Prix: 15,34 €
# Promotion: 1 acheté = 10% de remise
#
#
# Nom du produit: Rhum arrangé letchi passion ISAUTIER
# Prix: 14,53 €
# Promotion: 1 acheté = 10% de remise
#
#
# Nom du produit: Rhum  blanc agricole DILLON
# Prix: 13,55 €
# Promotion: 30% d'économies
#
#
# Nom du produit: Rhum arrangé saveur mandarine sauvage ISAUTIER
# Prix: 14,53 €
# Promotion: 1 acheté = 10% de remise
#
#
# ...
