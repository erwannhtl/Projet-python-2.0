# %%
pip install panda openpyxl
# Out:
# Requirement already satisfied: panda in /opt/mamba/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: openpyxl in /opt/mamba/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.10/site-packages (from panda) (68.1.2)
# Requirement already satisfied: requests in /opt/mamba/lib/python3.10/site-packages (from panda) (2.31.0)
# Requirement already satisfied: et-xmlfile in /opt/mamba/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.10/site-packages (from requests->panda) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.10/site-packages (from requests->panda) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/mamba/lib/python3.10/site-packages (from requests->panda) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/mamba/lib/python3.10/site-packages (from requests->panda) (2023.11.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
from interface import dic_profil
print(dic_profil)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 from interface import dic_profil
#       2 print(dic_profil)
#
# File ~/work/Projet-python-2.0/main/interface.py:6
#       3 from fuzzywuzzy import fuzz
#       4 import os
# ----> 6 os.chdir('main')
#       8 ## Première fenêtre expliquant les différents renseignements qui vont être demandés.
#      10 fenetre_intro = Tk()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'main'

# %%
mon_dictionnaire = {
    "10 ans" : ['10', '9-13','11-14','11-17','10-17'],
    "11 ans" : ['11','9-13','11-14', '11-17','10-17'],
    "12 ans" : ['12', '9-13','11-14','11-17','10-17'],
    "13 ans": ['13', '9-13','11-14', '11-17','10-17'],
    "14 ans" :['14','14-17','11-14', '11-17','10-17'],
    "15 ans": ['15','14-17','15-17', '11-17','10-17'],
    "16 ans": ['16','14-17','15-17', '11-17','10-17'],
    "17 ans": ['17','14-17','15-17', '11-17','10-17'],
    '18-29 ans': ['18–29', '18-24',	'≥ 18'],
    '30-39 ans': ['30–39',	'≥ 18'],
    '40-49 ans': ['40–49',	'≥ 18'],
    '50-59 ans': ['50–59',	'≥ 18'],
    '60-69 ans': ['60–69',	'≥ 18'],
    '70-79 ans': ['70–79',	'≥ 18'],
    '> 80 ans': ['80',	'≥ 18'],
    'Nulle': '1.4',
    'Faible': '1.6',
    'Régulière': '1.8',
    'Quotidienne': '2.0',
    'Homme': ['Male', 'Both genders'],
    'Femme': ['Female', 'Both genders'],
    'Je suis enceinte': 'Pregnant women',
    "J'allaite" : 'Lactating women'
}

# %%
def modifier_dic_profil(dic_profil):

    for cle, valeur in dic_profil.items():
        if cle == "age" and valeur in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
        elif cle in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
            
    for cle, valeur in dic_profil.items():
        if cle == "sexe" and valeur in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
        elif cle in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]

    for cle, valeur in dic_profil.items():
        if cle == "activité physique" and valeur in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
        elif cle in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
            
    for cle, valeur in dic_profil.items():
        if cle == "spécificités" and valeur in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
        elif cle in mon_dictionnaire:
            dic_profil[cle] = mon_dictionnaire[valeur]
    
    return dic_profil

# utilisation :
nouveau_dic_profil = modifier_dic_profil(dic_profil)
print(nouveau_dic_profil)
# Out:
# {'age': ['15', '14-17', '15-17', '11-17', '10-17'], 'sexe': ['Male', 'Both genders'], 'activité physique': '1.8', 'spécificités': ''}

# %%
import csv
import pandas as pd

def recherche_dans_csv(fichier_csv, colonne, valeurs_recherchees, fichier_resultat):
    resultats = []

    with open(fichier_csv, newline='', encoding='utf-8') as csvfile:
        lecteur_csv = csv.DictReader(csvfile)
        for ligne in lecteur_csv:
            if colonne in ligne and ligne[colonne] in valeurs_recherchees:
                resultats.append(ligne)

    return resultats

# Exemple d'utilisation :
fichier_csv = 'nouveau_fichier_DRVs.csv'
fichier_resultat = 'resultats_recherche.csv'

# Recherche pour la colonne "Years"
colonne_recherchee_years = "Years"
valeurs_recherchees_years = nouveau_dic_profil["age"]
resultats_years = recherche_dans_csv(fichier_csv, colonne_recherchee_years, valeurs_recherchees_years, fichier_resultat)

# Recherche pour la colonne "Gender"
colonne_recherchee_gender = "Gender"
valeurs_recherchees_gender = nouveau_dic_profil["sexe"]
resultats_gender = recherche_dans_csv(fichier_csv, colonne_recherchee_gender, valeurs_recherchees_gender, fichier_resultat)

# Convertir les résultats en DataFrames pandas
df_years = pd.DataFrame(resultats_years)
df_gender = pd.DataFrame(resultats_gender)

# Fusionner les résultats avec un merge sans spécifier de colonne commune
df_resultats = pd.merge(df_years, df_gender, how='inner')

# Enregistrer le résultat du join dans un fichier CSV
fichier_resultat_final = 'resultats_recherche_age_sexe.csv'
df_resultats.to_csv(fichier_resultat_final, index=False)

print(f"Le fichier final a été enregistré dans '{fichier_resultat_final}'.")
# Out:
# Le fichier final a été enregistré dans 'resultats_recherche_age_sexe.csv'.

# %%
import pandas as pd
import csv

# Charger le fichier CSV résultant
fichier_resultat = 'resultats_recherche_age_sexe.csv'
df_resultats = pd.read_csv(fichier_resultat)

# Entrer la valeur de PAL que vous recherchez
valeur_pal_recherchee = nouveau_dic_profil["activité physique"]

# Filtrer le DataFrame pour les valeurs de PAL spécifiées
df_filtre_pal = df_resultats[df_resultats['PAL'].astype(str).isin([valeur_pal_recherchee, '']) | df_resultats['PAL'].isna()]

# Afficher le DataFrame résultant pour PAL
print("DataFrame filtré pour PAL:")
print(df_filtre_pal)

# Définir une fonction de filtrage
def filtrer_dataframe(df_filtre_pal):
    # Filtrer les lignes selon la condition spécifiée
    condition = (
        (df_filtre_pal['Target population'] == 'Pregnant women') |
        (df_filtre_pal['Target population'] == 'Lactating women')
    )
    
    # Appliquer la condition supplémentaire pour 'Nutrient' égal à 'Energy' ou 'Protein'
    df_filtre = df_filtre_pal[condition & ((df_filtre_pal['Nutrient'] == 'Energy') | (df_filtre_pal['Nutrient'] == 'Protein'))]

    return df_filtre

# Appliquer la fonction de filtrage uniquement si 'Target population' est égal à 'Pregnant women' ou 'Lactating women'
# Vérifier si les conditions sont remplies avant d'appliquer la fonction de filtrage
if profil_recherche['spécificités'] in ['Lactating women', 'Pregnant women']:
    # Appliquer la fonction de filtrage
    df_filtre_final = filtrer_dataframe(df_filtre_pal)

    # Afficher le DataFrame final après le filtrage
    print("\nDataFrame final après filtrage:")
    print(df_filtre_final)

    # Enregistrer le DataFrame final dans un fichier CSV
    fichier_resultat_final = 'profil_final.csv'
    df_filtre_final.to_csv(fichier_resultat_final, index=False)
    print(f"Le fichier final a été enregistré dans '{fichier_resultat_final}'.")
else:
    # Si la fonction de filtrage n'est pas utilisée, enregistrer le DataFrame original dans un fichier CSV
    fichier_resultat_final = 'profil_final.csv'
    df_filtre_pal.to_csv(fichier_resultat_final, index=False)
    print(f"Le fichier final a été enregistré dans '{fichier_resultat_final}'.")
# Out:
# DataFrame filtré pour PAL:
#     Category                    Nutrient Target population               Age  \
# 1     Energy                      Energy          Children  15 years PAL=1.8
# 3    Protein                     Protein          Children          15 years
# 4      Water                       Water          Children       14-17 years
# 5   Minerals                     Calcium          Children       11-17 years
# 6   Minerals                   Magnesium          Children       10-17 years
# 7   Minerals                   Manganese          Children       15-17 years
# 8   Minerals                   Potassium          Children       15-17 years
# 9   Minerals                      Sodium          Children       11-17 years
# 10  Vitamins                  Vitamin B6          Children       15-17 years
# 11  Vitamins                   Vitamin C          Children       15-17 years
# 12  Vitamins                   Vitamin D          Children       15-17 years
# 13  Vitamins                   Vitamin E          Children       15-17 years
# 14  Vitamins  Vitamin K as phylloquinone          Children       15-17 years
#
#           Gender           AI                    AR                   PRI  \
# 1           Male          NA            12.7 MJ/day                  NA.
# 3           Male          NA   0.72 g/kg bw per day  0.88 g/kg bw per day
# 4           Male    2.5 L/day                   NA                    NA
# 5   Both genders          NA             960 mg/day           1150 mg/day
# 6           Male   300 mg/day                   NA                    NA
# 7   Both genders     3 mg/day                   NA                    NA
# 8   Both genders  3500 mg/day                   NA                    NA
# 9   Both genders          NA                    NA                    NA
# 10          Male          NA             1.5 mg/day            1.7 mg/day
# 11          Male          NA              85 mg/day            100 mg/day
# 12  Both genders    15 μg/day                   NA                    NA
# 13          Male    13 mg/day                   NA                    NA
# 14  Both genders    65 μg/day                   NA                    NA
#
#      RI          UL Safe and adequate intake  Years  PAL
# 1   NA          NA                       NaN     15  1.8
# 3   NA          NA                       NaN     15  NaN
# 4   NA          NA                       NaN  14-17  NaN
# 5   NA          ND                       NaN  11-17  NaN
# 6   NA   250 mg/day                      NaN  10-17  NaN
# 7   NA          ND                       NaN  15-17  NaN
# 8   NA          ND                       NaN  15-17  NaN
# 9   NA          ND                   2 g/day  11-17  NaN
# 10  NA    20 mg/day                      NaN  15-17  NaN
# 11  NA          ND                       NaN  15-17  NaN
# 12  NA   100 μg/day                      NaN  15-17  NaN
# 13  NA   260 mg/day                      NaN  15-17  NaN
# 14  NA          ND                       NaN  15-17  NaN
# Le fichier final a été enregistré dans 'profil_final.csv'.

# %%
import pandas as pd

# Charger le fichier CSV dans un dataframe avec le bon délimiteur
df = pd.read_csv('profil_final.csv', delimiter=',')

# Créer une fonction personnalisée pour la colonne 'New Column'
def choose_value(row):
    if row['AI'] != 'NA':
        return row['AI']
    elif row['AR'] != 'NA':
        return row['AR']
    elif row['Safe and adequate intake'] != 'NA':
        return row['Safe and adequate intake']
    else:
        return 'NA'

# Appliquer la fonction à la nouvelle colonne
df['New Column'] = df.apply(choose_value, axis=1)

# Afficher le dataframe résultant
print(df)
# Out:
#     Category                    Nutrient Target population               Age  \
# 0     Energy                      Energy          Children  15 years PAL=1.8
# 1    Protein                     Protein          Children          15 years
# 2      Water                       Water          Children       14-17 years
# 3   Minerals                     Calcium          Children       11-17 years
# 4   Minerals                   Magnesium          Children       10-17 years
# 5   Minerals                   Manganese          Children       15-17 years
# 6   Minerals                   Potassium          Children       15-17 years
# 7   Minerals                      Sodium          Children       11-17 years
# 8   Vitamins                  Vitamin B6          Children       15-17 years
# 9   Vitamins                   Vitamin C          Children       15-17 years
# 10  Vitamins                   Vitamin D          Children       15-17 years
# 11  Vitamins                   Vitamin E          Children       15-17 years
# 12  Vitamins  Vitamin K as phylloquinone          Children       15-17 years
#
#           Gender           AI                    AR                   PRI  \
# 0           Male          NA            12.7 MJ/day                  NA.
# 1           Male          NA   0.72 g/kg bw per day  0.88 g/kg bw per day
# 2           Male    2.5 L/day                   NA                    NA
# 3   Both genders          NA             960 mg/day           1150 mg/day
# 4           Male   300 mg/day                   NA                    NA
# 5   Both genders     3 mg/day                   NA                    NA
# 6   Both genders  3500 mg/day                   NA                    NA
# 7   Both genders          NA                    NA                    NA
# 8           Male          NA             1.5 mg/day            1.7 mg/day
# 9           Male          NA              85 mg/day            100 mg/day
# 10  Both genders    15 μg/day                   NA                    NA
# 11          Male    13 mg/day                   NA                    NA
# 12  Both genders    65 μg/day                   NA                    NA
#
#      RI          UL Safe and adequate intake  Years  PAL   New Column
# 0   NA          NA                       NaN     15  1.8          NA
# 1   NA          NA                       NaN     15  NaN          NA
# 2   NA          NA                       NaN  14-17  NaN    2.5 L/day
# 3   NA          ND                       NaN  11-17  NaN          NA
# 4   NA   250 mg/day                      NaN  10-17  NaN   300 mg/day
# 5   NA          ND                       NaN  15-17  NaN     3 mg/day
# 6   NA          ND                       NaN  15-17  NaN  3500 mg/day
# 7   NA          ND                   2 g/day  11-17  NaN          NA
# 8   NA    20 mg/day                      NaN  15-17  NaN          NA
# 9   NA          ND                       NaN  15-17  NaN          NA
# 10  NA   100 μg/day                      NaN  15-17  NaN    15 μg/day
# 11  NA   260 mg/day                      NaN  15-17  NaN    13 mg/day
# 12  NA          ND                       NaN  15-17  NaN    65 μg/day

# %%
import pandas as pd

# Charger le fichier CSV dans un dataframe avec le bon délimiteur
df = pd.read_csv('profil_final.csv', delimiter=',')

# Créer une fonction personnalisée pour la colonne 'Valeur_finale'
def choose_value(row):
    if str(row['AI']).strip() != 'NA':
        return str(row['AI']).strip()
    elif str(row['AR']).strip() != 'NA':
        return str(row['AR']).strip()
    elif str(row['Safe and adequate intake']).strip() != 'NA':
        return str(row['Safe and adequate intake']).strip()
    else:
        return 'NA'

# Appliquer la fonction à la nouvelle colonne
df['Valeur_finale'] = df.apply(choose_value, axis=1)

# Créer un nouveau dataframe avec les colonnes 'Nutrient' et 'Valeur_finale'
result_df = df[['Nutrient', 'Valeur_finale']]

# Afficher le dataframe résultant
print(result_df)
# Out:
#                       Nutrient         Valeur_finale
# 0                       Energy           12.7 MJ/day
# 1                      Protein  0.72 g/kg bw per day
# 2                        Water             2.5 L/day
# 3                      Calcium            960 mg/day
# 4                    Magnesium            300 mg/day
# 5                    Manganese              3 mg/day
# 6                    Potassium           3500 mg/day
# 7                       Sodium               2 g/day
# 8                   Vitamin B6            1.5 mg/day
# 9                    Vitamin C             85 mg/day
# 10                   Vitamin D             15 μg/day
# 11                   Vitamin E             13 mg/day
# 12  Vitamin K as phylloquinone             65 μg/day
